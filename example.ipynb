# %%
## (C) 2020 UvA FACT AI
import cem
mnist = cem.Main(seed=121, type='MNIST')
fmnist = cem.Main(seed=121, type='FMNIST')

# mnist.model_summary()
# fmnist.model_summary()

# %%
mnist.show_array(2953, kappa=10, max_iter=1000)
# Out:
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PP
#         time (s):    42.4
#         kappa:       10
#         gamma:       0
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       5 [ -6.8,  -5.6,  -7.8,  -6.5,  -7.8,   6.1,  -6.2,  -4.5,  -4.3,  -7.1]
#         Adversarial: 3 [-35.1, -19.6, -21.4,  18.5, -41.1,  -3.4, -35.5, -21.8, -18.4, -31.5]
#
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PP
#         time (s):    60.6
#         kappa:       10
#         gamma:       100
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       5 [ -7.7,  -5.3,  -7.5,  -5.3,  -8.3,   5.8,  -8.3,  -4.7,  -5.3,  -7.5]
#         Adversarial: 3 [-32.9, -17.8, -22.1,  13.4, -37.8,   2.5, -33.7, -19.9, -18.9, -26.7]
#
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PN
#         time (s):    44.8
#         kappa:       10
#         gamma:       0
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       1 [ -0.9,   0.9,  -0.5,  -0.9,  -1.0,  -1.3,  -1.3,  -0.9,  -0.4,  -0.9]
#         Adversarial: 3 [-34.8, -20.0, -24.8,  13.9, -41.8,   3.7, -36.0, -21.6, -20.3, -29.3]
#
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PN
#         time (s):    62.5
#         kappa:       10
#         gamma:       100
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       1 [ -0.6,   0.4,  -0.3,  -0.5,  -0.6,  -0.8,  -0.9,  -0.9,   0.1,  -0.5]
#         Adversarial: 3 [-34.7, -20.8, -25.1,  13.7, -42.3,   3.5, -35.6, -21.6, -20.3, -29.8]

# %%
mnist.show_array(2953, kappa=100, max_iter=1000)
# Out:
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PP
#         time (s):    44.5
#         kappa:       100
#         gamma:       0
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       5 [-65.0, -47.6, -67.4, -46.4, -75.5,  54.4, -53.0, -45.9, -46.2, -55.8]
#         Adversarial: 3 [-21.1, -12.4, -12.7,  12.5, -24.6,  -4.9, -21.8, -12.2, -10.8, -18.1]
#
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PP
#         time (s):    60.8
#         kappa:       100
#         gamma:       100
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       5 [-66.7, -49.3, -71.1, -48.0, -77.4,  55.4, -54.0, -46.6, -46.6, -56.3]
#         Adversarial: 3 [-25.7, -14.2, -15.7,  17.1, -30.5,  -8.9, -26.9, -13.7, -12.3, -22.6]
#
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PN
#         time (s):    42.7
#         kappa:       100
#         gamma:       0
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       8 [ -5.7,  -3.1,  -3.4,  -2.4,  -3.5,  -3.2,  -5.2,  -4.7,   3.7,  -5.3]
#         Adversarial: 3 [-74.7, -39.5, -45.3,  54.9, -82.0, -45.2, -81.9, -38.7, -45.9, -61.3]
#
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PN
#         time (s):    63.0
#         kappa:       100
#         gamma:       100
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       8 [ -7.3,  -4.0,  -4.7,  -5.1,  -1.1,  -3.8,  -6.9,  -4.0,   0.9,  -5.0]
#         Adversarial: 3 [-76.5, -41.8, -43.9,  57.2, -88.0, -42.8, -82.6, -41.9, -40.7, -66.3]

# %%
fmnist.show_array(2006, kappa=10, max_iter=1000)
# Out:
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PP
#         time (s):    43.0
#         kappa:       10
#         gamma:       0
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       6 [  2.1, -50.3, -17.7, -22.3, -34.8, -36.7,  18.5, -73.5,  -6.2, -36.7]
#         Adversarial: 6 [ -1.4, -33.2, -47.8,  -5.7, -19.8, -46.3,   5.6, -51.2, -35.6, -34.1]
#
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PP
#         time (s):    61.7
#         kappa:       10
#         gamma:       100
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       6 [  1.2, -37.6, -14.3, -19.0, -35.8, -33.8,  12.6, -68.7,  -3.8, -28.2]
#         Adversarial: 0 [ -1.5, -40.2, -52.6, -12.0, -25.6, -44.8,  -3.7, -50.0, -38.4, -27.9]
#
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PN
#         time (s):    45.8
#         kappa:       10
#         gamma:       0
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       8 [  1.6, -17.3, -23.2, -11.4, -25.6, -10.6, -14.9, -24.1,  11.7,  -6.2]
#         Adversarial: 0 [  5.3, -33.4, -43.5, -15.3, -23.1, -45.9,  -5.4, -51.7, -40.9, -27.3]
#
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PN
#         time (s):    60.3
#         kappa:       10
#         gamma:       100
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       8 [  0.3, -17.6, -21.4, -12.0, -22.1,  -9.0, -15.8, -23.8,  12.5,  -5.6]
#         Adversarial: 0 [  5.7, -32.1, -42.5, -13.9, -22.7, -43.8,  -4.4, -50.4, -39.0, -26.9]

# %%
fmnist.show_array(2006, kappa=100, max_iter=1000)
# Out:
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PP
#         time (s):    41.9
#         kappa:       100
#         gamma:       0
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       6 [-42.1, -89.0, -76.7, -43.2, -64.7, -187.4,  61.4, -210.1, -77.7, -176.0]
#         Adversarial: 3 [-10.9, -39.6, -47.9,   4.5, -15.6, -52.2,   4.5, -45.3, -37.2, -40.2]
#
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PP
#         time (s):    59.7
#         kappa:       100
#         gamma:       100
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       6 [-53.7, -151.6, -64.2, -87.0, -79.2, -196.9,  71.1, -288.4, -115.7, -212.7]
#         Adversarial: 6 [ -3.1, -39.6, -39.1, -17.2, -26.6, -42.0,   8.0, -37.2, -17.3, -29.9]
#
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PN
#         time (s):    41.9
#         kappa:       100
#         gamma:       0
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       8 [-18.0, -22.6, -32.5, -16.7, -36.7, -35.6, -22.6, -50.5,  13.4, -25.4]
#         Adversarial: 0 [ 45.0, -76.9, -21.9, -45.4, -47.2, -77.8, -55.7, -93.2, -78.0, -34.9]
#
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PN
#         time (s):    60.2
#         kappa:       100
#         gamma:       100
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       8 [-10.7, -30.6, -14.5, -14.7, -29.0, -45.2, -26.2, -54.5,  16.8, -35.9]
#         Adversarial: 0 [ 56.3, -71.6, -24.2, -46.3, -64.4, -80.6, -51.8, -100.3, -82.7, -46.2]
