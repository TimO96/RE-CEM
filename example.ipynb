# %%
## (C) 2020 UvA FACT AI
import cem
mnist = cem.Main(seed=121, type='MNIST')
fmnist = cem.Main(seed=121, type='FMNIST')

# mnist.model_summary()
# fmnist.model_summary()

# %%
mnist.show_array(2953, kappa=10, max_iter=1000)
# Out:
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PP
#         time (s):    43.4
#         kappa:       100
#         gamma:       0
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       5 [-65.0, -47.6, -67.8, -46.2, -75.6,  55.0, -52.8, -46.4, -45.6, -55.9]
#         Adversarial: 3 [-21.0, -12.2, -13.0,  12.8, -24.0,  -5.8, -22.1, -10.6, -10.5, -17.2]
#
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PP
#         time (s):    61.4
#         kappa:       100
#         gamma:       100
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       5 [-66.3, -46.5, -68.3, -45.2, -76.2,  55.0, -53.2, -47.3, -47.0, -56.0]
#         Adversarial: 3 [-25.8, -16.4, -15.8,  15.5, -30.7,  -7.7, -26.4, -14.8, -12.3, -23.0]
#
# Image:2953, infer label:5
#
#         [INFO]
# ...

# %%
fmnist.show_array(2006, max_iter=1000)
# Out:
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PP
#         time (s):    42.2
#         kappa:       10
#         gamma:       0
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       6 [  2.1, -38.0, -14.7, -16.2, -24.0, -25.8,  13.2, -58.0,  -5.0, -28.7]
#         Adversarial: 6 [ -0.3, -37.9, -51.2,  -7.6, -24.4, -46.3,   1.0, -52.7, -34.6, -30.8]
#
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PP
#         time (s):    60.9
#         kappa:       10
#         gamma:       100
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       6 [  1.8, -35.2,  -7.2, -15.1, -18.6, -24.4,  13.0, -48.1,  -5.3, -24.4]
#         Adversarial: 6 [  1.3, -33.9, -47.5,  -9.6, -18.8, -48.3,   3.7, -53.2, -36.9, -33.7]
#
# Image:2006, infer label:6
#
#         [INFO]
# ...
