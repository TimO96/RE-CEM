# %%
## (C) 2020 UvA FACT AI
import cem
mnist = cem.Main(seed=121, type='MNIST')
fmnist = cem.Main(seed=121, type='FMNIST')

# mnist.model_summary()
# fmnist.model_summary()

# %%
mnist.show_array(12, kappa=10, max_iter=1000)
# Out:
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    44.2
#         kappa:       10
#         gamma:       0
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [ -6.9,  -8.4,  -8.3,  -5.9,  -4.6,  -5.2, -14.2,  -8.0,  -5.6,   5.7]
#         Adversarial: 9 [-37.6, -45.1, -41.9, -34.3, -22.8, -24.5, -61.4, -29.9, -32.0,  24.8]
#
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    66.4
#         kappa:       10
#         gamma:       100
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [-13.1, -16.0, -15.0, -11.9,  -5.7,  -9.1, -22.4, -14.3, -10.5,   8.0]
#         Adversarial: 9 [-26.7, -31.4, -31.6, -23.5, -19.8, -20.1, -46.1, -23.4, -23.2,  17.2]
#
# Image:12, infer label:9
#
#         [INFO]
# ...

# %%
fmnist.show_array(12, kappa=10, max_iter=1000)
# Out:
# Image:12, infer label:5
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    49.2
#         kappa:       10
#         gamma:       0
#         Original:    5 [-44.9, -56.3, -22.2, -39.7, -42.2,  18.9, -41.8,   7.9, -46.9, -13.3]
#         Delta:       5 [-36.8, -64.8, -20.4, -46.6, -49.2,  -3.0, -62.4, -42.9, -18.9, -14.2]
#         Adversarial: 5 [-57.7, -62.6, -27.6, -43.9, -54.2,  30.8, -52.3,  11.0, -58.4, -23.4]
#
# Image:12, infer label:5
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    65.7
#         kappa:       10
#         gamma:       100
#         Original:    5 [-44.9, -56.3, -22.2, -39.7, -42.2,  18.9, -41.8,   7.9, -46.9, -13.3]
#         Delta:       5 [-40.0, -87.6, -17.5, -62.1, -58.0,  -5.5, -63.6, -44.5, -20.2, -15.6]
#         Adversarial: 5 [-49.9, -57.6, -28.7, -30.5, -51.3,  20.7, -46.3,  -0.1, -43.7,  -9.4]
#
# Image:12, infer label:5
#
#         [INFO]
# ...

# %%
mnist.show_array(2953, kappa=10, max_iter=1000)
# Out:
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PP
#         time (s):    45.8
#         kappa:       10
#         gamma:       0
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       5 [ -6.5,  -4.3,  -7.7,  -5.8,  -6.5,   6.2,  -7.2,  -5.0,  -5.2,  -6.0]
#         Adversarial: 3 [-34.1, -17.5, -22.3,  11.7, -38.7,   5.0, -34.5, -21.4, -19.3, -28.1]
#
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PP
#         time (s):    71.0
#         kappa:       10
#         gamma:       100
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       5 [ -7.4,  -5.6,  -8.7,  -5.4,  -8.5,   6.5,  -7.8,  -5.6,  -5.1,  -6.8]
#         Adversarial: 3 [-34.0, -18.2, -22.6,  14.3, -39.4,   1.3, -34.2, -20.7, -19.8, -28.7]
#
# Image:2953, infer label:5
#
#         [INFO]
# ...

# %%
mnist.show_array(2953, kappa=100, max_iter=1000)
# Out:
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PP
#         time (s):    47.4
#         kappa:       100
#         gamma:       0
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       5 [-65.3, -48.1, -67.7, -45.6, -76.0,  54.4, -53.2, -45.9, -45.8, -56.2]
#         Adversarial: 3 [-22.9, -15.5, -13.5,  13.3, -27.4,  -5.5, -23.4, -14.4, -10.0, -20.6]
#
# Image:2953, infer label:5
#
#         [INFO]
#         id:          2953
#         mode:        PP
#         time (s):    61.1
#         kappa:       100
#         gamma:       100
#         Original:    5 [-33.9, -19.9, -26.8,   7.4, -40.9,  10.9, -35.5, -22.0, -21.3, -27.5]
#         Delta:       5 [-66.3, -47.4, -70.3, -46.3, -76.9,  55.1, -53.0, -47.3, -46.8, -55.6]
#         Adversarial: 3 [-27.3, -15.5, -16.4,  17.4, -33.1,  -7.7, -28.4, -17.2, -13.9, -23.9]
#
# Image:2953, infer label:5
#
#         [INFO]
# ...

# %%
fmnist.show_array(2006, kappa=10, max_iter=1000)
# Out:
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PP
#         time (s):    48.0
#         kappa:       10
#         gamma:       0
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       6 [  3.6, -41.1, -19.1, -20.5, -34.1, -32.4,  15.9, -64.9,  -1.5, -28.4]
#         Adversarial: 6 [  1.3, -31.4, -42.9,  -8.3, -18.6, -45.8,   6.2, -50.1, -35.4, -32.9]
#
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PP
#         time (s):    66.0
#         kappa:       10
#         gamma:       100
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       6 [ -0.7, -29.3,  -6.5, -11.0, -17.7, -27.9,  12.7, -53.0,  -7.1, -26.2]
#         Adversarial: 6 [ -0.5, -38.1, -49.5, -10.2, -21.0, -50.5,   6.0, -53.3, -36.3, -34.9]
#
# Image:2006, infer label:6
#
#         [INFO]
# ...

# %%
fmnist.show_array(2006, kappa=100, max_iter=1000)
# Out:
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PP
#         time (s):    41.9
#         kappa:       100
#         gamma:       0
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       6 [-45.5, -100.4, -59.1, -43.6, -62.7, -162.0,  56.5, -211.7, -74.7, -165.0]
#         Adversarial: 6 [ -8.5, -40.9, -49.8, -10.2, -22.5, -42.9,   2.5, -49.3, -25.4, -34.5]
#
# Image:2006, infer label:6
#
#         [INFO]
#         id:          2006
#         mode:        PP
#         time (s):    59.3
#         kappa:       100
#         gamma:       100
#         Original:    6 [  0.9, -35.0, -47.7, -11.7, -20.8, -49.1,   4.3, -52.6, -39.0, -32.5]
#         Delta:       6 [-46.9, -156.1, -52.1, -100.1, -82.3, -185.5,  70.3, -261.8, -106.1, -194.3]
#         Adversarial: 3 [ -4.3, -40.9, -58.3,  -1.2, -38.7, -43.6,  -6.3, -61.3, -25.9, -37.3]
#
# Image:2006, infer label:6
#
# ...
