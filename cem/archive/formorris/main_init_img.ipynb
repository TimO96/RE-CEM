# %%
## (C) 2020 UvA FACT AI
from main import Main

# %%
pp = Main(mode='PP', report=False, max_iter=1000, gamma=0, seed=121)
pn = Main(mode='PN', report=False, max_iter=1000, gamma=0, seed=121)
pp_ae = Main(mode='PP', report=False, max_iter=1000, gamma=100, seed=121)
pn_ae = Main(mode='PN', report=False, max_iter=1000, gamma=100, seed=121)

# %%
def run_all(id, pp=pp, pn=pn, pp_ae=pp_ae, pn_ae=pn_ae):
    """Run all models."""
    pp.run(id); pn.run(id); pp_ae.run(id); pn_ae.run(id)

# %%
run_all(12)
# Out:
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    63.2
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Adversarial: 1 [ -0.8,   0.8,  -0.4,  -0.8,  -0.9,  -1.1,  -1.2,  -0.6,  -0.4,  -0.9]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PN
#         time (s):    63.6
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       8 [ -1.9,  -1.2,  -2.1,  -1.1,  -2.0,   0.1,  -2.4,  -0.8,   0.3,  -2.7]
#         Adversarial: 4 [-30.4, -23.1, -15.2, -20.6,   9.1, -18.2, -30.5, -12.6, -24.6,  -2.4]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    96.3
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [-13.8, -17.4, -16.6, -11.6, -12.0,  -5.1, -25.5, -16.3,  -6.2,   5.7]
#         Adversarial: 9 [-39.5, -42.9, -38.7, -35.0, -20.3, -22.2, -58.2, -25.9, -33.3,  24.5]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PN
#         time (s):    102.4
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       8 [ -4.7,  -2.9,  -2.6,  -3.3,  -1.6,  -2.7,  -3.7,  -3.8,   2.5,  -4.5]
#         Adversarial: 4 [-24.8, -18.2, -12.4, -20.6,   9.7, -15.1, -24.2, -13.4, -17.9,  -2.0]

# %%
run_all(4321)
# Out:
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PP
#         time (s):    77.5
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Adversarial: 1 [ -0.8,   0.8,  -0.4,  -0.8,  -0.9,  -1.1,  -1.2,  -0.6,  -0.4,  -0.9]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PN
#         time (s):    65.2
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [ -0.9,  -0.8,  -0.7,  -1.3,  -0.9,  -1.3,  -1.5,  -1.7,  -0.3,   0.1]
#         Adversarial: 8 [-18.3, -28.9, -31.8, -22.2, -39.3, -24.8, -43.4, -28.8,   4.4,  -5.9]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PP
#         time (s):    103.9
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [-11.6, -15.9, -15.9, -13.0,  -8.6,  -9.1, -23.7, -14.1,  -8.7,   9.7]
#         Adversarial: 9 [-16.3, -26.1, -27.6, -20.1, -24.3, -15.2, -36.2, -25.8, -12.3,  17.8]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PN
#         time (s):    96.3
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       8 [ -5.6,  -5.1,  -3.0,  -6.0,  -5.1,  -6.7,  -9.6,  -8.1,   4.4,  -3.5]
#         Adversarial: 8 [ -5.3, -33.8, -34.3, -23.1, -38.9, -20.7, -31.3, -25.0,  -1.3, -13.6]
