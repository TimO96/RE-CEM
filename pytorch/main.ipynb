# %%
## (C) 2020 UvA FACT AI
from main import Main

# %%
pp = Main(mode='PP', report=False, max_iter=1000, gamma=0, seed=121)
pn = Main(mode='PN', report=False, max_iter=1000, gamma=0, seed=121)
pp_ae = Main(mode='PP', report=False, max_iter=1000, gamma=100, seed=121)
pn_ae = Main(mode='PN', report=False, max_iter=1000, gamma=100, seed=121)

# %%
def run_all(id, pp=pp, pn=pn, pp_ae=pp_ae, pn_ae=pn_ae):
    """Run all models."""
    pp.run(id); pn.run(id); pp_ae.run(id); pn_ae.run(id)

# %%
run_all(12)
# Out:
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    41.3
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Adversarial: 1 [ -0.8,   0.8,  -0.4,  -0.8,  -0.9,  -1.1,  -1.2,  -0.6,  -0.4,  -0.9]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PN
#         time (s):    41.1
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       8 [ -1.9,  -0.6,  -2.5,  -1.9,  -0.5,  -0.0,  -2.1,  -1.5,   0.1,  -2.9]
#         Adversarial: 4 [-31.0, -23.2, -15.7, -22.6,   9.9, -19.6, -30.1, -12.1, -25.7,  -1.3]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    59.1
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [ -8.2, -11.8, -10.9,  -9.3,  -6.5,  -5.5, -16.7, -10.9,  -5.8,   6.9]
#         Adversarial: 9 [-32.9, -35.7, -32.0, -27.5, -13.2, -21.0, -48.4, -22.8, -28.0,  18.4]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PN
#         time (s):    58.7
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       4 [ -3.9,  -0.4,  -0.2,  -2.7,   0.6,  -2.7,  -2.3,  -1.5,  -2.2,  -3.1]
#         Adversarial: 4 [-50.5, -30.2, -22.8, -27.9,   7.5, -29.5, -45.9, -14.7, -39.4,  -2.9]

# %%
run_all(4321)
# Out:
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PP
#         time (s):    42.0
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Adversarial: 1 [ -0.8,   0.8,  -0.4,  -0.8,  -0.9,  -1.1,  -1.2,  -0.6,  -0.4,  -0.9]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PN
#         time (s):    41.0
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [ -0.9,  -0.9,  -0.8,  -1.3,  -0.8,  -1.2,  -1.3,  -1.8,  -0.1,  -0.0]
#         Adversarial: 8 [-18.7, -29.2, -32.0, -22.0, -39.3, -24.9, -44.1, -29.4,   4.6,  -5.7]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PP
#         time (s):    58.8
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [-10.7,  -6.3,  -7.4,  -5.4,  -4.9,  -5.9, -16.3,  -7.5,  -9.3,   5.2]
#         Adversarial: 9 [-35.6, -42.8, -46.7, -33.5, -35.2, -26.3, -68.5, -35.9, -34.2,  28.5]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PN
#         time (s):    60.5
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       8 [ -2.2,  -1.9,  -0.7,  -2.3,  -1.6,  -3.0,  -3.3,  -3.2,  0.0,  -0.2]
#         Adversarial: 8 [-19.4, -28.7, -31.7, -21.7, -39.4, -25.1, -44.1, -29.0,   5.1,  -6.0]
