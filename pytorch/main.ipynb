# %%
## (C) 2020 UvA FACT AI
from main import Main
from torch.cuda import empty_cache

# %%
# del pp; del pn; del pp_ae; del pn_ae
# empty_cache()

# %%
args = {'report':False, 'max_iter':1000, 'seed':121, 'type':'FMNIST'}
pp = Main(mode='PP', gamma=0, **args)
pn = Main(mode='PN', gamma=0, **args)
pp_ae = Main(mode='PP', gamma=100, **args)
pn_ae = Main(mode='PN', gamma=100, **args)

# %%
def run_all(id, pp=pp, pn=pn, pp_ae=pp_ae, pn_ae=pn_ae):
    """Run all models."""
    pp.run(id); pn.run(id); pp_ae.run(id); pn_ae.run(id)

# %%
run_all(12)
# Out:
# Image:12, infer label:5
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    56.9
#         kappa:       10
#         Original:    5 [ -2.8,  -5.9,  -4.0,  -5.8,  -7.3,   6.0,  -6.2,   5.4,   1.0,  -0.4]
#         Delta:       5 [ -2.8,  -5.9,  -4.0,  -5.8,  -7.3,   6.0,  -6.2,   5.4,   1.0,  -0.4]
#         Adversarial: 8 [  0.2,  -1.0,  -0.4,  -1.2,  -2.0,  -0.8,  -0.8,  -0.5,   3.4,  -0.3]
# Image:12, infer label:5
#
#         [INFO]
#         id:          12
#         mode:        PN
#         time (s):    57.1
#         kappa:       10
#         Original:    5 [ -2.8,  -5.9,  -4.0,  -5.8,  -7.3,   6.0,  -6.2,   5.4,   1.0,  -0.4]
#         Delta:       8 [ -0.4,  -0.6,  -1.6,  -1.5,  -2.6,  -0.3,  -1.8,   0.5,   3.0,  0.0]
#         Adversarial: 8 [ -0.3,  -3.6,  -2.5,  -5.7,  -4.1,   0.1,  -3.9,  -0.3,  10.1,  -0.9]
# Image:12, infer label:5
#
#         [INFO]
#         id:          12
#         mode:        PP
# ...

# %%
run_all(4321)
# Out:
# Image:4321, infer label:1
#
#         [INFO]
#         id:          4321
#         mode:        PP
#         time (s):    57.7
#         kappa:       10
#         Original:    1 [  1.6,  12.6,  -3.4,  -2.0,  -1.0,  -7.7,  -0.7, -12.4,  -2.5, -10.4]
#         Delta:       1 [  1.6,  12.6,  -3.4,  -2.0,  -1.0,  -7.7,  -0.7, -12.4,  -2.5, -10.4]
#         Adversarial: 8 [  0.2,  -1.0,  -0.4,  -1.2,  -2.0,  -0.8,  -0.8,  -0.5,   3.4,  -0.3]
# Image:4321, infer label:1
#
#         [INFO]
#         id:          4321
#         mode:        PN
#         time (s):    57.4
#         kappa:       10
#         Original:    1 [  1.6,  12.6,  -3.4,  -2.0,  -1.0,  -7.7,  -0.7, -12.4,  -2.5, -10.4]
#         Delta:       8 [ -0.5,   3.0,  -1.8,  -2.7,  -1.9,  -0.6,  -1.8,  -1.6,   3.1,  -2.1]
#         Adversarial: 0 [  9.3,  -0.8,  -0.2,   0.4,  -4.9,  -7.8,   3.2, -13.6,  -2.3,  -8.1]
# Image:4321, infer label:1
#
#         [INFO]
#         id:          4321
#         mode:        PP
# ...
