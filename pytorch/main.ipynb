# %%
## (C) 2020 UvA FACT AI
from main import Main

# %%
pp = Main(mode='PP', report=False, max_iter=1000, gamma=0)
pn = Main(mode='PN', report=False, max_iter=1000, gamma=0)
pp_ae = Main(mode='PP', report=False, max_iter=1000, gamma=100)
pn_ae = Main(mode='PN', report=False, max_iter=1000, gamma=100)

# %%
def run_all(id, pp=pp, pn=pn, pp_ae=pp_ae, pn_ae=pn_ae):
    """Run all models."""
    pp.run(id); pn.run(id); pp_ae.run(id); pn_ae.run(id)

# %%
run_all(12)
# Out:
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    58.2
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Adversarial: 1 [ -0.8,   0.8,  -0.4,  -0.8,  -0.9,  -1.1,  -1.2,  -0.6,  -0.4,  -0.9]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PN
#         time (s):    56.1
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       8 [ -1.9,  -1.2,  -2.1,  -1.1,  -2.0,   0.1,  -2.4,  -0.8,   0.3,  -2.7]
#         Adversarial: 4 [-30.4, -23.1, -15.2, -20.6,   9.1, -18.2, -30.5, -12.6, -24.6,  -2.4]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    87.1
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [-11.5, -11.1, -10.9,  -9.9,  -3.9,  -7.6, -17.6,  -9.4,  -6.9,   6.2]
#         Adversarial: 9 [-44.0, -54.1, -48.1, -37.7, -27.8, -30.6, -72.4, -33.7, -42.3,  30.3]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PN
#         time (s):    85.0
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       8 [ -3.3,  -1.5,  -3.4,  -2.6,  -1.9,  -1.8,  -3.2,  -3.6,   2.1,  -3.6]
#         Adversarial: 4 [-23.7, -18.1, -13.0, -20.5,   8.0, -13.5, -23.2, -15.2, -14.5,  -2.2]

# %%
run_all(4321)
# Out:
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PP
#         time (s):    54.7
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Adversarial: 1 [ -0.8,   0.8,  -0.4,  -0.8,  -0.9,  -1.1,  -1.2,  -0.6,  -0.4,  -0.9]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PN
#         time (s):    54.4
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [ -0.9,  -0.8,  -0.7,  -1.3,  -0.9,  -1.3,  -1.5,  -1.7,  -0.3,   0.1]
#         Adversarial: 8 [-18.3, -28.9, -31.8, -22.2, -39.3, -24.8, -43.4, -28.8,   4.4,  -5.9]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PP
#         time (s):    78.3
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [ -7.2,  -9.7, -10.9,  -5.3,  -7.0,  -6.9, -15.4,  -9.4,  -8.7,   6.4]
#         Adversarial: 9 [-24.0, -27.1, -30.9, -25.4, -18.4, -20.2, -47.7, -25.9, -20.8,  21.9]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PN
#         time (s):    80.5
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [ -5.0,  -2.7,  -3.6,  -1.9,  -1.8,  -2.9,  -7.7,  -4.6,  -2.8,   1.8]
#         Adversarial: 0 [ -3.4, -33.3, -33.3, -34.4, -35.0, -13.2, -33.3,  -8.0, -19.1, -22.8]
