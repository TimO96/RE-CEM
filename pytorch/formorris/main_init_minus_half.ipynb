# %%
## (C) 2020 UvA FACT AI
from main import Main

# %%
pp = Main(mode='PP', report=False, max_iter=1000, seed=121, gamma=0)
pn = Main(mode='PN', report=False, max_iter=1000, seed=121, gamma=0)
pp_ae = Main(mode='PP', report=False, max_iter=1000, seed=121, gamma=100)
pn_ae = Main(mode='PN', report=False, max_iter=1000, seed=121, gamma=100)

# %%
def run_all(id, pp=pp, pn=pn, pp_ae=pp_ae, pn_ae=pn_ae):
    """Run all models."""
    pp.run(id); pn.run(id); pp_ae.run(id); pn_ae.run(id)

# %%
run_all(12)
# Out:
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    46.9
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [ -5.5,  -8.7,  -8.8,  -7.3,  -5.1,  -4.6, -12.9,  -7.7,  -4.6,   5.6]
#         Adversarial: 9 [-35.5, -44.2, -40.8, -32.9, -24.8, -26.1, -60.8, -29.3, -31.8,  24.0]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PN
#         time (s):    47.7
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       5 [ -2.1,  -2.0,  -2.7,  -1.6,  -2.6,   0.6,  -2.8,  -1.1,   0.2,  -3.2]
#         Adversarial: 4 [-30.2, -23.2, -15.6, -20.2,   8.6, -17.7, -30.9, -12.5, -24.5,  -1.8]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
# ...

# %%
run_all(4321)
# Out:
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PP
#         time (s):    48.0
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [-10.2,  -6.6,  -7.4,  -6.0,  -4.6,  -5.6, -16.3,  -7.8,  -8.0,   5.5]
#         Adversarial: 9 [-37.1, -46.5, -49.5, -36.3, -37.1, -26.6, -71.3, -37.4, -35.3,  29.0]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PN
#         time (s):    46.4
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [ -0.8,  -0.8,  -0.6,  -1.1,  -0.8,  -1.2,  -1.3,  -1.6,  -0.1,  0.0]
#         Adversarial: 8 [-18.5, -29.3, -31.8, -22.1, -39.4, -25.0, -44.0, -29.5,   4.4,  -5.6]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PP
# ...
