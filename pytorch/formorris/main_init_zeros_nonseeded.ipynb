# %%
## (C) 2020 UvA FACT AI
from main import Main

# %%
pp = Main(mode='PP', report=False, max_iter=1000, gamma=0)
pn = Main(mode='PN', report=False, max_iter=1000, gamma=0)
pp_ae = Main(mode='PP', report=False, max_iter=1000, gamma=100)
pn_ae = Main(mode='PN', report=False, max_iter=1000, gamma=100)

# %%
def run_all(id, pp=pp, pn=pn, pp_ae=pp_ae, pn_ae=pn_ae):
    """Run all models."""
    pp.run(id); pn.run(id); pp_ae.run(id); pn_ae.run(id)

# %%
run_all(12)
# Out:
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    54.3
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [ -6.9,  -8.2,  -7.8,  -6.5,  -5.0,  -5.0, -12.6,  -6.0,  -5.3,   5.2]
#         Adversarial: 9 [-32.6, -39.3, -35.4, -29.5, -17.0, -20.0, -51.6, -23.2, -29.2,  21.1]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PN
#         time (s):    53.4
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       2 [ -4.3,  -0.5,   0.3,  -1.9,  -1.0,  -3.1,  -2.9,  -2.0,  -0.7,  -5.1]
#         Adversarial: 4 [-41.1, -26.0, -19.5, -23.5,   6.4, -26.1, -37.4, -11.5, -34.0,  -4.0]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
# ...

# %%
run_all(4321)
# Out:
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PP
#         time (s):    61.3
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [-10.0,  -7.3,  -7.7,  -6.1,  -4.8,  -5.2, -16.6,  -8.0,  -8.0,   5.8]
#         Adversarial: 9 [-36.6, -46.0, -48.9, -35.8, -36.8, -26.0, -70.4, -36.7, -35.1,  28.3]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PN
#         time (s):    60.1
#         kappa:       10
#         Original:    9 [-46.0, -54.1, -57.7, -41.6, -41.6, -34.4, -88.7, -50.7, -41.3,  39.3]
#         Delta:       9 [ -1.1,  -1.1,  -0.5,  -1.5,  -1.3,  -1.6,  -1.7,  -1.7,  -0.6,  -0.2]
#         Adversarial: 8 [-18.3, -28.0, -32.2, -23.0, -39.3, -25.3, -43.2, -27.3,   5.0,  -6.1]
# Image:4321, infer label:9
#
#         [INFO]
#         id:          4321
#         mode:        PP
# ...
