# %%
## (C) 2020 UvA FACT AI
import cem
m = cem.Main(mode='PP', seed=121, type='MNIST')
# m.model_summary()

# %%
def run_all(id, m, modes=['PP', 'PN'], gammas=[0,100], **args):
    """Run all models."""
    for mode in modes:
        m.set_mode(mode)
        for gamma in gammas:
            m.explain(id, gamma=gamma, **args)

# %%
args = {'report':False, 'max_iter':10}

# %%
run_all(12, m, **args)
# Out:
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    1.0
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Adversarial: 1 [ -0.8,   0.8,  -0.4,  -0.8,  -0.9,  -1.1,  -1.2,  -0.6,  -0.4,  -0.9]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    1.1
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       9 [-20.2, -22.5, -18.0, -16.1,  -6.4, -11.5, -30.2, -13.4, -16.3,   9.6]
#         Adversarial: 7 [-16.0, -10.3,  -9.7,  -9.8, -13.7,  -0.1, -18.7,   2.9, -14.5,  -9.4]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PN
#         time (s):    0.9
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       8 [ -1.7,  -1.3,  -1.8,  -1.7,  -0.5,  -0.9,  -2.5,  -1.0,  -0.2,  -0.3]
#         Adversarial: 4 [-28.1, -21.1, -15.2, -23.0,  10.1, -17.0, -27.2, -13.7, -22.1,  -1.0]
# Image:12, infer label:9
#
#         [INFO]
#         id:          12
#         mode:        PN
#         time (s):    1.2
#         kappa:       10
#         Original:    9 [-49.3, -65.7, -61.8, -47.4, -37.1, -36.4, -88.4, -46.8, -46.9,  37.0]
#         Delta:       8 [ -3.9,  -2.4,  -2.3,  -3.4,  -0.8,  -2.7,  -3.4,  -3.6,   1.9,  -3.1]
#         Adversarial: 4 [-27.2, -20.0, -14.9, -24.0,  10.8, -16.9, -26.9, -15.9, -20.0,  -2.4]

# %%
m2 = cem.Main(mode='PP', seed=121, type='FMNIST')
m2.explain(12, **args)
# Out:
# Image:12, infer label:5
#
#         [INFO]
#         id:          12
#         mode:        PP
#         time (s):    1.2
#         kappa:       10
#         Original:    5 [-44.9, -56.3, -22.2, -39.7, -42.2,  18.9, -41.8,   7.9, -46.9, -13.3]
#         Delta:       5 [-44.9, -56.3, -22.2, -39.7, -42.2,  18.9, -41.8,   7.9, -46.9, -13.3]
#         Adversarial: 8 [ -1.3, -17.5, -22.2, -12.9, -21.5,  -9.3, -18.7, -24.9,  12.3,  -7.0]
