# %%
## (C) 2020 UvA FACT AI
import cem
m = cem.Main(mode='PP', seed=121, type='MNIST')
# m.model_summary()

m.quant_eval(ids=[1,2])
# Out:
# s_Elastic:0.966
# Loss_attack:387.660, Loss_L2:0.716, Loss_L1:2.499
# lab_score:52.255, max_nontarget_lab_score:-33.169
#
# iter: 0 const: 4.21875
# Loss_Overall:643.302, Loss_Elastic:5.087
# Loss_attack:365.735, Loss_L2:3.577, Loss_L1:15.106
# lab_score:47.198, max_nontarget_lab_score:-29.495
#
# iter: 100 const: 4.21875
# Loss_Overall:700.960, Loss_Elastic:9.438
# Loss_attack:308.121, Loss_L2:7.418, Loss_L1:20.196
# lab_score:39.489, max_nontarget_lab_score:-23.547
#
# iter: 200 const: 4.21875
# Loss_Overall:736.095, Loss_Elastic:9.454
# Loss_attack:314.935, Loss_L2:7.408, Loss_L1:20.463
# lab_score:39.726, max_nontarget_lab_score:-24.925
#
# iter: 300 const: 4.21875
# Loss_Overall:624.982, Loss_Elastic:7.893
# Loss_attack:299.425, Loss_L2:6.112, Loss_L1:17.802
# lab_score:37.841, max_nontarget_lab_score:-23.134
#
# iter: 400 const: 4.21875
# Loss_Overall:596.947, Loss_Elastic:5.590
# Loss_attack:323.251, Loss_L2:4.239, Loss_L1:13.506
# lab_score:41.167, max_nontarget_lab_score:-25.456
#
# iter: 500 const: 4.21875
# Loss_Overall:602.404, Loss_Elastic:4.592
# Loss_attack:333.554, Loss_L2:3.420, Loss_L1:11.719
# lab_score:42.528, max_nontarget_lab_score:-26.536
#
# iter: 600 const: 4.21875
# Loss_Overall:617.266, Loss_Elastic:3.559
# Loss_attack:348.956, Loss_L2:2.570, Loss_L1:9.885
# lab_score:44.539, max_nontarget_lab_score:-28.176
#
# iter: 700 const: 4.21875
# Loss_Overall:650.547, Loss_Elastic:2.662
# Loss_attack:363.519, Loss_L2:1.898, Loss_L1:7.638
# lab_score:46.634, max_nontarget_lab_score:-29.533
#
# iter: 800 const: 4.21875
# Loss_Overall:683.686, Loss_Elastic:2.061
# Loss_attack:376.919, Loss_L2:1.475, Loss_L1:5.856
# lab_score:48.519, max_nontarget_lab_score:-30.825
#
# iter: 900 const: 4.21875
# Loss_Overall:754.691, Loss_Elastic:1.001
# Loss_attack:401.328, Loss_L2:0.739, Loss_L1:2.623
# lab_score:52.107, max_nontarget_lab_score:-33.023
#
# iter: 0 const: 4.296875
# Loss_Overall:647.506, Loss_Elastic:5.128
# Loss_attack:368.151, Loss_L2:3.619, Loss_L1:15.086
# lab_score:46.645, max_nontarget_lab_score:-29.034
#
# iter: 100 const: 4.296875
# Loss_Overall:864.679, Loss_Elastic:14.713
# Loss_attack:330.695, Loss_L2:12.029, Loss_L1:26.843
# lab_score:41.272, max_nontarget_lab_score:-25.690
#
# iter: 200 const: 4.296875
# Loss_Overall:710.422, Loss_Elastic:7.535
# Loss_attack:323.128, Loss_L2:5.746, Loss_L1:17.896
# lab_score:40.428, max_nontarget_lab_score:-24.773
#
# iter: 300 const: 4.296875
# Loss_Overall:634.602, Loss_Elastic:5.149
# Loss_attack:329.980, Loss_L2:3.739, Loss_L1:14.101
# lab_score:41.059, max_nontarget_lab_score:-25.737
#
# iter: 400 const: 4.296875
# Loss_Overall:625.147, Loss_Elastic:5.125
# Loss_attack:349.696, Loss_L2:3.744, Loss_L1:13.804
# lab_score:43.608, max_nontarget_lab_score:-27.776
#
# iter: 500 const: 4.296875
# Loss_Overall:618.245, Loss_Elastic:3.828
# Loss_attack:348.285, Loss_L2:2.685, Loss_L1:11.424
# lab_score:43.582, max_nontarget_lab_score:-27.474
#
# iter: 600 const: 4.296875
# Loss_Overall:627.760, Loss_Elastic:3.358
# Loss_attack:365.631, Loss_L2:2.397, Loss_L1:9.611
# lab_score:46.016, max_nontarget_lab_score:-29.077
#
# iter: 700 const: 4.296875
# Loss_Overall:650.154, Loss_Elastic:2.837
# Loss_attack:367.809, Loss_L2:2.033, Loss_L1:8.038
# lab_score:46.314, max_nontarget_lab_score:-29.285
#
# iter: 800 const: 4.296875
# Loss_Overall:689.138, Loss_Elastic:2.037
# Loss_attack:381.307, Loss_L2:1.445, Loss_L1:5.917
# lab_score:48.153, max_nontarget_lab_score:-30.588
#
# iter: 900 const: 4.296875
# Loss_Overall:759.704, Loss_Elastic:1.001
# Loss_attack:406.615, Loss_L2:0.727, Loss_L1:2.744
# lab_score:51.886, max_nontarget_lab_score:-32.745
#
# iter: 0 const: 4.3359375
# Loss_Overall:651.503, Loss_Elastic:5.131
# Loss_attack:372.148, Loss_L2:3.618, Loss_L1:15.132
# lab_score:46.850, max_nontarget_lab_score:-28.979
#
# iter: 100 const: 4.3359375
# Loss_Overall:904.116, Loss_Elastic:16.141
# Loss_attack:303.509, Loss_L2:13.531, Loss_L1:26.096
# lab_score:36.343, max_nontarget_lab_score:-23.656
#
# iter: 200 const: 4.3359375
# Loss_Overall:696.640, Loss_Elastic:10.354
# Loss_attack:312.671, Loss_L2:8.268, Loss_L1:20.863
# lab_score:38.481, max_nontarget_lab_score:-23.630
#
# iter: 300 const: 4.3359375
# Loss_Overall:630.859, Loss_Elastic:6.220
# Loss_attack:326.092, Loss_L2:4.630, Loss_L1:15.893
# lab_score:40.558, max_nontarget_lab_score:-24.648
#
# iter: 400 const: 4.3359375
# Loss_Overall:606.396, Loss_Elastic:5.153
# Loss_attack:330.494, Loss_L2:3.830, Loss_L1:13.235
# lab_score:40.856, max_nontarget_lab_score:-25.366
#
# iter: 500 const: 4.3359375
# Loss_Overall:607.609, Loss_Elastic:4.526
# Loss_attack:340.343, Loss_L2:3.320, Loss_L1:12.056
# lab_score:42.139, max_nontarget_lab_score:-26.354
#
# iter: 600 const: 4.3359375
# Loss_Overall:633.358, Loss_Elastic:3.306
# Loss_attack:363.966, Loss_L2:2.356, Loss_L1:9.500
# lab_score:45.378, max_nontarget_lab_score:-28.563
#
# iter: 700 const: 4.3359375
# Loss_Overall:657.581, Loss_Elastic:2.738
# Loss_attack:373.517, Loss_L2:1.961, Loss_L1:7.777
# lab_score:46.648, max_nontarget_lab_score:-29.496
#
# iter: 800 const: 4.3359375
# Loss_Overall:690.636, Loss_Elastic:2.082
# Loss_attack:381.980, Loss_L2:1.480, Loss_L1:6.026
# lab_score:47.786, max_nontarget_lab_score:-30.310
#
# iter: 900 const: 4.3359375
# Loss_Overall:765.283, Loss_Elastic:0.975
# Loss_attack:410.963, Loss_L2:0.709, Loss_L1:2.664
# lab_score:51.942, max_nontarget_lab_score:-32.838
#
# Image:2, infer label:1
# iter: 0 const: 10.0
# Loss_Overall:961.236, Loss_Elastic:12.563
# Loss_attack:484.400, Loss_L2:10.227, Loss_L1:23.353
# lab_score:17.746, max_nontarget_lab_score:-20.694
#
# iter: 100 const: 10.0
# Loss_Overall:505.097, Loss_Elastic:11.291
# Loss_attack:0.000, Loss_L2:9.224, Loss_L1:20.664
# lab_score:-13.833, max_nontarget_lab_score:15.641
#
# iter: 200 const: 10.0
# Loss_Overall:346.579, Loss_Elastic:13.412
# Loss_attack:0.000, Loss_L2:11.008, Loss_L1:24.034
# lab_score:-18.942, max_nontarget_lab_score:14.008
#
# iter: 300 const: 10.0
# Loss_Overall:732.344, Loss_Elastic:23.945
# Loss_attack:0.000, Loss_L2:20.699, Loss_L1:32.457
# lab_score:-23.415, max_nontarget_lab_score:20.782
#
# iter: 400 const: 10.0
# Loss_Overall:290.202, Loss_Elastic:14.248
# Loss_attack:0.000, Loss_L2:11.796, Loss_L1:24.520
# lab_score:-10.632, max_nontarget_lab_score:11.821
#
# iter: 500 const: 10.0
# Loss_Overall:779.938, Loss_Elastic:25.303
# Loss_attack:0.000, Loss_L2:21.640, Loss_L1:36.626
# lab_score:-26.721, max_nontarget_lab_score:24.254
#
# iter: 600 const: 10.0
# Loss_Overall:427.864, Loss_Elastic:6.280
# Loss_attack:123.623, Loss_L2:5.095, Loss_L1:11.849
# lab_score:2.675, max_nontarget_lab_score:0.313
#
# iter: 700 const: 10.0
# Loss_Overall:238.914, Loss_Elastic:8.503
# Loss_attack:0.000, Loss_L2:6.984, Loss_L1:15.192
# lab_score:-14.258, max_nontarget_lab_score:16.937
#
# iter: 800 const: 10.0
# Loss_Overall:262.649, Loss_Elastic:8.672
# Loss_attack:0.000, Loss_L2:7.265, Loss_L1:14.072
# lab_score:-16.381, max_nontarget_lab_score:18.225
#
# iter: 900 const: 10.0
# Loss_Overall:325.059, Loss_Elastic:6.828
# Loss_attack:0.000, Loss_L2:5.811, Loss_L1:10.176
# lab_score:-14.912, max_nontarget_lab_score:17.665
#
# iter: 0 const: 5.0
# Loss_Overall:562.548, Loss_Elastic:5.935
# Loss_attack:298.476, Loss_L2:4.472, Loss_L1:14.637
# lab_score:23.246, max_nontarget_lab_score:-26.449
#
# iter: 100 const: 5.0
# Loss_Overall:318.288, Loss_Elastic:8.066
# Loss_attack:29.416, Loss_L2:6.575, Loss_L1:14.912
# lab_score:1.855, max_nontarget_lab_score:5.972
#
# iter: 200 const: 5.0
# Loss_Overall:323.842, Loss_Elastic:10.445
# Loss_attack:0.000, Loss_L2:8.427, Loss_L1:20.178
# lab_score:-11.559, max_nontarget_lab_score:17.603
#
# iter: 300 const: 5.0
# Loss_Overall:257.839, Loss_Elastic:10.092
# Loss_attack:0.000, Loss_L2:8.275, Loss_L1:18.168
# lab_score:-7.246, max_nontarget_lab_score:16.047
#
# iter: 400 const: 5.0
# Loss_Overall:306.636, Loss_Elastic:6.843
# Loss_attack:70.961, Loss_L2:5.432, Loss_L1:14.109
# lab_score:5.207, max_nontarget_lab_score:1.014
#
# iter: 500 const: 5.0
# Loss_Overall:225.201, Loss_Elastic:7.724
# Loss_attack:10.215, Loss_L2:6.315, Loss_L1:14.091
# lab_score:-0.412, max_nontarget_lab_score:7.545
#
# iter: 600 const: 5.0
# Loss_Overall:234.100, Loss_Elastic:6.179
# Loss_attack:23.617, Loss_L2:4.950, Loss_L1:12.288
# lab_score:1.386, max_nontarget_lab_score:6.663
#
# iter: 700 const: 5.0
# Loss_Overall:219.608, Loss_Elastic:6.260
# Loss_attack:0.000, Loss_L2:5.163, Loss_L1:10.973
# lab_score:-0.929, max_nontarget_lab_score:9.679
#
# iter: 800 const: 5.0
# Loss_Overall:340.648, Loss_Elastic:4.092
# Loss_attack:92.267, Loss_L2:3.327, Loss_L1:7.649
# lab_score:7.854, max_nontarget_lab_score:-0.599
#
# iter: 900 const: 5.0
# Loss_Overall:342.090, Loss_Elastic:4.069
# Loss_attack:53.790, Loss_L2:3.453, Loss_L1:6.157
# lab_score:5.171, max_nontarget_lab_score:4.413
#
# iter: 0 const: 2.5
# Loss_Overall:378.323, Loss_Elastic:4.238
# Loss_attack:166.769, Loss_L2:3.053, Loss_L1:11.848
# lab_score:27.460, max_nontarget_lab_score:-29.248
#
# iter: 100 const: 2.5
# Loss_Overall:378.752, Loss_Elastic:12.458
# Loss_attack:0.000, Loss_L2:10.382, Loss_L1:20.757
# lab_score:-9.221, max_nontarget_lab_score:16.896
#
# iter: 200 const: 2.5
# Loss_Overall:320.791, Loss_Elastic:10.393
# Loss_attack:0.000, Loss_L2:8.609, Loss_L1:17.848
# lab_score:-12.873, max_nontarget_lab_score:17.593
#
# iter: 300 const: 2.5
# Loss_Overall:269.723, Loss_Elastic:8.349
# Loss_attack:0.000, Loss_L2:6.788, Loss_L1:15.617
# lab_score:-5.917, max_nontarget_lab_score:13.156
#
# iter: 400 const: 2.5
# Loss_Overall:274.089, Loss_Elastic:7.881
# Loss_attack:0.000, Loss_L2:6.450, Loss_L1:14.311
# lab_score:-10.142, max_nontarget_lab_score:15.963
#
# iter: 500 const: 2.5
# Loss_Overall:241.927, Loss_Elastic:6.841
# Loss_attack:0.000, Loss_L2:5.523, Loss_L1:13.179
# lab_score:-4.878, max_nontarget_lab_score:12.333
#
# iter: 600 const: 2.5
# Loss_Overall:224.165, Loss_Elastic:6.831
# Loss_attack:0.000, Loss_L2:5.587, Loss_L1:12.445
# lab_score:-4.747, max_nontarget_lab_score:12.431
#
# iter: 700 const: 2.5
# Loss_Overall:225.968, Loss_Elastic:5.237
# Loss_attack:6.227, Loss_L2:4.217, Loss_L1:10.199
# lab_score:1.121, max_nontarget_lab_score:8.630
#
# iter: 800 const: 2.5
# Loss_Overall:236.877, Loss_Elastic:4.824
# Loss_attack:11.913, Loss_L2:3.937, Loss_L1:8.867
# lab_score:2.154, max_nontarget_lab_score:7.389
#
# iter: 900 const: 2.5
# Loss_Overall:284.499, Loss_Elastic:4.108
# Loss_attack:16.227, Loss_L2:3.422, Loss_L1:6.859
# lab_score:3.568, max_nontarget_lab_score:7.077
#
# iter: 0 const: 1.25
# Loss_Overall:280.133, Loss_Elastic:3.371
# Loss_attack:88.857, Loss_L2:2.409, Loss_L1:9.621
# lab_score:29.430, max_nontarget_lab_score:-31.656
#
# iter: 100 const: 1.25
# Loss_Overall:348.858, Loss_Elastic:4.332
# Loss_attack:82.630, Loss_L2:3.256, Loss_L1:10.762
# lab_score:26.266, max_nontarget_lab_score:-29.838
#
# iter: 200 const: 1.25
# Loss_Overall:285.217, Loss_Elastic:3.262
# Loss_attack:86.546, Loss_L2:2.375, Loss_L1:8.873
# lab_score:28.932, max_nontarget_lab_score:-30.304
#
# iter: 300 const: 1.25
# Loss_Overall:274.873, Loss_Elastic:1.860
# Loss_attack:88.872, Loss_L2:1.244, Loss_L1:6.162
# lab_score:29.861, max_nontarget_lab_score:-31.236
#
# iter: 400 const: 1.25
# Loss_Overall:264.656, Loss_Elastic:1.858
# Loss_attack:87.124, Loss_L2:1.219, Loss_L1:6.396
# lab_score:28.937, max_nontarget_lab_score:-30.763
#
# iter: 500 const: 1.25
# Loss_Overall:270.665, Loss_Elastic:1.592
# Loss_attack:90.300, Loss_L2:1.076, Loss_L1:5.157
# lab_score:30.280, max_nontarget_lab_score:-31.960
#
# iter: 600 const: 1.25
# Loss_Overall:281.272, Loss_Elastic:1.246
# Loss_attack:92.832, Loss_L2:0.830, Loss_L1:4.157
# lab_score:31.287, max_nontarget_lab_score:-32.979
#
# iter: 700 const: 1.25
# Loss_Overall:289.549, Loss_Elastic:1.096
# Loss_attack:93.732, Loss_L2:0.733, Loss_L1:3.634
# lab_score:31.652, max_nontarget_lab_score:-33.334
#
# iter: 800 const: 1.25
# Loss_Overall:313.920, Loss_Elastic:0.552
# Loss_attack:92.964, Loss_L2:0.322, Loss_L1:2.303
# lab_score:31.706, max_nontarget_lab_score:-32.665
#
# iter: 900 const: 1.25
# Loss_Overall:351.581, Loss_Elastic:0.139
# Loss_attack:96.320, Loss_L2:0.067, Loss_L1:0.714
# lab_score:33.526, max_nontarget_lab_score:-33.530
#
# iter: 0 const: 1.875
# Loss_Overall:325.433, Loss_Elastic:3.442
# Loss_attack:121.152, Loss_L2:2.403, Loss_L1:10.387
# lab_score:26.105, max_nontarget_lab_score:-28.509
#
# iter: 100 const: 1.875
# Loss_Overall:350.499, Loss_Elastic:9.965
# Loss_attack:0.000, Loss_L2:8.178, Loss_L1:17.870
# lab_score:-15.809, max_nontarget_lab_score:13.787
#
# iter: 200 const: 1.875
# Loss_Overall:288.697, Loss_Elastic:12.501
# Loss_attack:0.000, Loss_L2:10.559, Loss_L1:19.416
# lab_score:-22.101, max_nontarget_lab_score:19.554
#
# iter: 300 const: 1.875
# Loss_Overall:251.565, Loss_Elastic:10.414
# Loss_attack:0.000, Loss_L2:8.801, Loss_L1:16.132
# lab_score:-22.144, max_nontarget_lab_score:20.068
#
# iter: 400 const: 1.875
# Loss_Overall:228.211, Loss_Elastic:9.292
# Loss_attack:0.000, Loss_L2:7.764, Loss_L1:15.277
# lab_score:-20.383, max_nontarget_lab_score:18.066
#
# iter: 500 const: 1.875
# Loss_Overall:241.242, Loss_Elastic:8.715
# Loss_attack:0.000, Loss_L2:7.360, Loss_L1:13.545
# lab_score:-19.852, max_nontarget_lab_score:17.774
#
# iter: 600 const: 1.875
# Loss_Overall:259.177, Loss_Elastic:7.417
# Loss_attack:0.000, Loss_L2:6.278, Loss_L1:11.393
# lab_score:-16.649, max_nontarget_lab_score:16.160
#
# iter: 700 const: 1.875
# Loss_Overall:250.445, Loss_Elastic:6.742
# Loss_attack:0.000, Loss_L2:5.741, Loss_L1:10.017
# lab_score:-13.562, max_nontarget_lab_score:14.489
#
# iter: 800 const: 1.875
# Loss_Overall:263.765, Loss_Elastic:5.789
# Loss_attack:0.000, Loss_L2:4.948, Loss_L1:8.413
# lab_score:-8.977, max_nontarget_lab_score:11.616
#
# iter: 900 const: 1.875
# Loss_Overall:307.548, Loss_Elastic:3.537
# Loss_attack:10.727, Loss_L2:2.985, Loss_L1:5.524
# lab_score:0.089, max_nontarget_lab_score:4.368
#
# iter: 0 const: 1.5625
# Loss_Overall:302.610, Loss_Elastic:3.190
# Loss_attack:109.030, Loss_L2:2.229, Loss_L1:9.605
# lab_score:29.323, max_nontarget_lab_score:-30.456
#
# iter: 100 const: 1.5625
# Loss_Overall:350.409, Loss_Elastic:4.345
# Loss_attack:101.456, Loss_L2:3.284, Loss_L1:10.604
# lab_score:27.512, max_nontarget_lab_score:-27.419
#
# iter: 200 const: 1.5625
# Loss_Overall:346.970, Loss_Elastic:2.972
# Loss_attack:107.949, Loss_L2:2.137, Loss_L1:8.350
# lab_score:28.853, max_nontarget_lab_score:-30.235
#
# iter: 300 const: 1.5625
# Loss_Overall:308.887, Loss_Elastic:2.142
# Loss_attack:109.830, Loss_L2:1.473, Loss_L1:6.688
# lab_score:29.658, max_nontarget_lab_score:-30.633
#
# iter: 400 const: 1.5625
# Loss_Overall:298.019, Loss_Elastic:1.642
# Loss_attack:112.252, Loss_L2:1.095, Loss_L1:5.472
# lab_score:30.326, max_nontarget_lab_score:-31.515
#
# iter: 500 const: 1.5625
# Loss_Overall:294.612, Loss_Elastic:1.597
# Loss_attack:108.544, Loss_L2:1.071, Loss_L1:5.254
# lab_score:29.188, max_nontarget_lab_score:-30.280
#
# iter: 600 const: 1.5625
# Loss_Overall:298.480, Loss_Elastic:1.370
# Loss_attack:111.333, Loss_L2:0.902, Loss_L1:4.679
# lab_score:29.867, max_nontarget_lab_score:-31.386
#
# iter: 700 const: 1.5625
# Loss_Overall:312.508, Loss_Elastic:1.036
# Loss_attack:114.751, Loss_L2:0.671, Loss_L1:3.648
# lab_score:30.915, max_nontarget_lab_score:-32.526
#
# iter: 800 const: 1.5625
# Loss_Overall:337.929, Loss_Elastic:0.557
# Loss_attack:116.405, Loss_L2:0.329, Loss_L1:2.275
# lab_score:31.735, max_nontarget_lab_score:-32.765
#
# iter: 900 const: 1.5625
# Loss_Overall:373.496, Loss_Elastic:0.153
# Loss_attack:119.874, Loss_L2:0.074, Loss_L1:0.784
# lab_score:33.294, max_nontarget_lab_score:-33.426
#
# iter: 0 const: 1.71875
# Loss_Overall:309.517, Loss_Elastic:3.492
# Loss_attack:117.570, Loss_L2:2.485, Loss_L1:10.066
# lab_score:28.085, max_nontarget_lab_score:-30.319
#
# iter: 100 const: 1.71875
# Loss_Overall:391.973, Loss_Elastic:8.041
# Loss_attack:27.133, Loss_L2:6.545, Loss_L1:14.957
# lab_score:2.660, max_nontarget_lab_score:-3.127
#
# iter: 200 const: 1.71875
# Loss_Overall:309.605, Loss_Elastic:5.656
# Loss_attack:66.099, Loss_L2:4.436, Loss_L1:12.205
# lab_score:13.563, max_nontarget_lab_score:-14.895
#
# iter: 300 const: 1.71875
# Loss_Overall:291.216, Loss_Elastic:4.936
# Loss_attack:96.074, Loss_L2:3.896, Loss_L1:10.404
# lab_score:22.891, max_nontarget_lab_score:-23.007
#
# iter: 400 const: 1.71875
# Loss_Overall:275.723, Loss_Elastic:4.545
# Loss_attack:70.364, Loss_L2:3.619, Loss_L1:9.267
# lab_score:14.691, max_nontarget_lab_score:-16.248
#
# iter: 500 const: 1.71875
# Loss_Overall:259.351, Loss_Elastic:4.394
# Loss_attack:71.548, Loss_L2:3.488, Loss_L1:9.061
# lab_score:16.057, max_nontarget_lab_score:-15.571
#
# iter: 600 const: 1.71875
# Loss_Overall:279.667, Loss_Elastic:3.703
# Loss_attack:95.384, Loss_L2:2.964, Loss_L1:7.395
# lab_score:22.719, max_nontarget_lab_score:-22.777
#
# iter: 700 const: 1.71875
# Loss_Overall:286.424, Loss_Elastic:2.603
# Loss_attack:96.376, Loss_L2:1.960, Loss_L1:6.430
# lab_score:23.204, max_nontarget_lab_score:-22.869
#
# iter: 800 const: 1.71875
# Loss_Overall:322.462, Loss_Elastic:1.538
# Loss_attack:117.770, Loss_L2:1.095, Loss_L1:4.423
# lab_score:29.087, max_nontarget_lab_score:-29.434
#
# iter: 900 const: 1.71875
# Loss_Overall:383.275, Loss_Elastic:0.171
# Loss_attack:131.393, Loss_L2:0.085, Loss_L1:0.864
# lab_score:33.173, max_nontarget_lab_score:-33.274
#
# iter: 0 const: 1.640625
# Loss_Overall:310.227, Loss_Elastic:3.565
# Loss_attack:116.538, Loss_L2:2.535, Loss_L1:10.303
# lab_score:29.549, max_nontarget_lab_score:-31.484
#
# iter: 100 const: 1.640625
# Loss_Overall:331.294, Loss_Elastic:7.312
# Loss_attack:62.500, Loss_L2:5.873, Loss_L1:14.391
# lab_score:13.766, max_nontarget_lab_score:-14.329
#
# iter: 200 const: 1.640625
# Loss_Overall:300.303, Loss_Elastic:4.979
# Loss_attack:77.791, Loss_L2:3.918, Loss_L1:10.619
# lab_score:19.822, max_nontarget_lab_score:-17.594
#
# iter: 300 const: 1.640625
# Loss_Overall:250.664, Loss_Elastic:4.743
# Loss_attack:76.317, Loss_L2:3.731, Loss_L1:10.125
# lab_score:18.374, max_nontarget_lab_score:-18.143
#
# iter: 400 const: 1.640625
# Loss_Overall:261.840, Loss_Elastic:4.466
# Loss_attack:78.576, Loss_L2:3.543, Loss_L1:9.230
# lab_score:19.705, max_nontarget_lab_score:-18.189
#
# iter: 500 const: 1.640625
# Loss_Overall:274.721, Loss_Elastic:3.527
# Loss_attack:84.722, Loss_L2:2.753, Loss_L1:7.740
# lab_score:21.060, max_nontarget_lab_score:-20.580
#
# iter: 600 const: 1.640625
# Loss_Overall:277.195, Loss_Elastic:3.517
# Loss_attack:97.787, Loss_L2:2.796, Loss_L1:7.212
# lab_score:24.525, max_nontarget_lab_score:-25.079
#
# iter: 700 const: 1.640625
# Loss_Overall:317.257, Loss_Elastic:1.047
# Loss_attack:119.721, Loss_L2:0.677, Loss_L1:3.708
# lab_score:30.708, max_nontarget_lab_score:-32.265
#
# iter: 800 const: 1.640625
# Loss_Overall:341.077, Loss_Elastic:0.561
# Loss_attack:120.190, Loss_L2:0.322, Loss_L1:2.390
# lab_score:31.113, max_nontarget_lab_score:-32.145
#
# iter: 900 const: 1.640625
# Loss_Overall:377.981, Loss_Elastic:0.167
# Loss_attack:125.671, Loss_L2:0.083, Loss_L1:0.836
# lab_score:33.228, max_nontarget_lab_score:-33.371
#
# iter: 0 const: 1.6796875
# Loss_Overall:309.263, Loss_Elastic:3.177
# Loss_attack:116.676, Loss_L2:2.223, Loss_L1:9.538
# lab_score:28.963, max_nontarget_lab_score:-30.501
#
# iter: 100 const: 1.6796875
# Loss_Overall:316.431, Loss_Elastic:8.534
# Loss_attack:32.882, Loss_L2:6.913, Loss_L1:16.204
# lab_score:5.111, max_nontarget_lab_score:-4.465
#
# iter: 200 const: 1.6796875
# Loss_Overall:321.789, Loss_Elastic:4.660
# Loss_attack:73.889, Loss_L2:3.633, Loss_L1:10.269
# lab_score:17.644, max_nontarget_lab_score:-16.346
#
# iter: 300 const: 1.6796875
# Loss_Overall:265.384, Loss_Elastic:4.353
# Loss_attack:72.482, Loss_L2:3.413, Loss_L1:9.405
# lab_score:17.230, max_nontarget_lab_score:-15.922
#
# iter: 400 const: 1.6796875
# Loss_Overall:251.737, Loss_Elastic:6.036
# Loss_attack:33.834, Loss_L2:4.852, Loss_L1:11.841
# lab_score:5.365, max_nontarget_lab_score:-4.778
#
# iter: 500 const: 1.6796875
# Loss_Overall:253.026, Loss_Elastic:4.440
# Loss_attack:71.372, Loss_L2:3.506, Loss_L1:9.340
# lab_score:16.135, max_nontarget_lab_score:-16.356
#
# iter: 600 const: 1.6796875
# Loss_Overall:265.933, Loss_Elastic:3.826
# Loss_attack:79.169, Loss_L2:2.999, Loss_L1:8.271
# lab_score:18.772, max_nontarget_lab_score:-18.361
#
# iter: 700 const: 1.6796875
# Loss_Overall:288.627, Loss_Elastic:2.517
# Loss_attack:104.932, Loss_L2:1.900, Loss_L1:6.172
# lab_score:25.767, max_nontarget_lab_score:-26.704
#
# iter: 800 const: 1.6796875
# Loss_Overall:344.969, Loss_Elastic:0.560
# Loss_attack:123.617, Loss_L2:0.323, Loss_L1:2.365
# lab_score:31.295, max_nontarget_lab_score:-32.300
#
# iter: 900 const: 1.6796875
# Loss_Overall:379.575, Loss_Elastic:0.178
# Loss_attack:128.444, Loss_L2:0.090, Loss_L1:0.887
# lab_score:33.180, max_nontarget_lab_score:-33.290
# 1.0

# %%
def run_all(id, m, modes=['PP', 'PN'], gammas=[0,100], **args):
    """Run all models."""
    for mode in modes:
        m.set_mode(mode)
        for gamma in gammas:
            m.explain(id, gamma=gamma, **args)

# %%
args = {'report':False, 'max_iter':10}

# %%
run_all(12, m, **args)
# Out:
# Image:12, infer label:9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-42719e879656> in <module>
# ----> 1 run_all(12, m, **args)
#
# <ipython-input-2-d775fd49304d> in run_all(id, m, modes, gammas, **args)
#       4         m.set_mode(mode)
#       5         for gamma in gammas:
# ----> 6             m.explain(id, gamma=gamma, **args)
#
# /mnt/hdd/Stefan/Documents/GitHub/FACTAI/cem/main.py in explain(self, id, mode, object, show, **kwargs)
#      85
#      86         explain = CEM(nn=self.nn, ae=self.ae, dvc=self.dvc, mode=mode, **kwargs)
# ---> 87         explain.run(self.data, id, show)
#      88
#      89         if object:
#
# /mnt/hdd/Stefan/Documents/GitHub/FACTAI/cem/main.py in run(self, data, id, show)
#     242         """Run the algorithm for specific image."""
#     243         self.set_image(data, id)
# --> 244         self.attack()
#     245         self.report()
#     246         self.store_images()
#
# TypeError: 'Attack' object is not callable

# %%
m2 = cem.Main(mode='PP', seed=121, type='FMNIST')
m2.explain(12, **args)
